# %% [markdown]
# # 🌍 Understanding Our 12-Channel Multispectral Data
#
# Unlike standard RGB images, our dataset consists of **12-channel harmonized satellite imagery** (Sentinel-2/Landsat). These invisible bands and auxiliary geographical data layers are critical for accurately segmenting water bodies.
#
#
#
# ### 📊 Band Breakdown & Significance
#
# Our model takes an input shape of `(Height, Width, 12)`. Here is what each index `[0 to 11]` represents:
#
# #### 1. Optical & Infrared Bands (Reflectance Data)
# These bands capture sunlight reflected off the Earth. The infrared spectrum is our most powerful tool for this task.
# * **`Band 0` - Coastal Aerosol (~443nm):** Deep blue/violet light. Penetrates shallow water well and detects atmospheric particles.
# * **`Band 1` - Blue (~490nm):** Visible blue light. Good for clear water penetration.
# * **`Band 2` - Green (~560nm):** Visible green light. Highlights turbidity (muddiness) in water.
# * **`Band 3` - Red (~665nm):** Visible red light. Strongly reflects off bare soil and urban areas.
# * **`Band 4` - NIR (Near-Infrared, ~842nm):** **⭐ CRITICAL FOR WATER SEGMENTATION.** Water absorbs almost all NIR light (appearing pitch black), while land and vegetation reflect it heavily (appearing bright white).
# * **`Band 5` - SWIR1 & `Band 6` - SWIR2 (Short-Wave Infrared):** Highly sensitive to moisture content. Helps distinguish wet soil from dry soil and penetrates thin clouds.
#
# #### 2. Quality Assessment
# * **`Band 7` - QA Band:** A pixel-level bitmask indicating the presence of clouds, cloud shadows, or snow, which could otherwise confuse the model.
#
# #### 3. Topography & Elevation (3D Context)
# Water naturally flows to and settles in areas of low elevation.
# * **`Band 8` - MERIT DEM:** Digital Elevation Model with vegetation and buildings removed (bare earth elevation).
# * **`Band 9` - Copernicus DEM:** Digital Surface Model that includes the heights of forests and infrastructure.
#
# #### 4. Historical & Categorical Priors
# These layers act as statistical "hints" for the neural network.
# * **`Band 10` - ESA WorldCover Map:** A discrete classification map where each pixel is pre-labeled with a land cover type (e.g., Trees, Urban, Permanent Water).
# * **`Band 11` - Water Occurrence Probability (JRC):** A heatmap (0-100) indicating how frequently water has been observed at this specific pixel over the past few decades.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import rasterio # For loading the images that have the extension (".tif")
import cv2
from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import os
import shutil
from tqdm import tqdm
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, Concatenate, BatchNormalization, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import roc_curve, auc
from tensorflow.keras.models import load_model

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.2)

# %%
# dataset_root_folder = "/content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation"
# dataset_name = "data"

# %%
# # os.walk() returns three values (the path, subdirectories, and files)
# for path, subdirs, files in os.walk(dataset_root_folder):
#   print(subdirs)

# %%
# for path, subdirs, files in os.walk(os.path.join(dataset_root_folder, dataset_name)):
#   dir_name = path.split(os.path.sep)[-1]
#   print(dir_name)

#   if dir_name == "images": # you can change it to "labels"
#     images = os.listdir(path)
#     print(images)
#     for i, image_name in enumerate(images): # get the index and the image names
#       if (image_name.endswith(".tif")): # Check the extension of the images, You can change it to ".png"

#         print(f"Image {i}: image name is {image_name}")

# %% [markdown]
# # Read the images

# %%
data_dir = "/content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/data"

# %%
images_dir = os.path.join(data_dir, "images")
print(images_dir)
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/data/images

# %%
files = os.listdir(images_dir)
print(files)
# Out:
# ['0.tif', '1.tif', '3.tif', '8.tif', '5.tif', '7.tif', '9.tif', '6.tif', '4.tif', '10.tif', '16.tif', '12.tif', '14.tif', '13.tif', '11.tif', '15.tif', '17.tif', '23.tif', '18.tif', '22.tif', '19.tif', '20.tif', '21.tif', '24.tif', '25.tif', '27.tif', '26.tif', '29.tif', '28.tif', '33.tif', '30.tif', '35.tif', '36.tif', '31.tif', '34.tif', '32.tif', '37.tif', '40.tif', '38.tif', '42.tif', '39.tif', '41.tif', '43.tif', '48.tif', '44.tif', '46.tif', '49.tif', '47.tif', '45.tif', '50.tif', '51.tif', '55.tif', '54.tif', '52.tif', '56.tif', '53.tif', '60.tif', '62.tif', '63.tif', '61.tif', '58.tif', '57.tif', '59.tif', '64.tif', '71.tif', '67.tif', '66.tif', '70.tif', '65.tif', '69.tif', '68.tif', '76.tif', '72.tif', '77.tif', '73.tif', '75.tif', '74.tif', '80.tif', '81.tif', '78.tif', '84.tif', '79.tif', '82.tif', '83.tif', '91.tif', '87.tif', '86.tif', '90.tif', '85.tif', '89.tif', '88.tif', '93.tif', '92.tif', '96.tif', '94.tif', '97.tif', '95.tif', '100.tif', '103.tif', '105.tif', '98.tif', '102.tif', '99.tif', '101.tif', '104.tif', '108.tif', '109.tif', '111.tif', '106.tif', '107.tif', '110.tif', '115.tif', '114.tif', '113.tif', '117.tif', '118.tif', '112.tif', '116.tif', '121.tif', '123.tif', '122.tif', '125.tif', '120.tif', '124.tif', '119.tif', '127.tif', '130.tif', '126.tif', '132.tif', '131.tif', '128.tif', '129.tif', '134.tif', '136.tif', '137.tif', '133.tif', '138.tif', '135.tif', '143.tif', '142.tif', '140.tif', '141.tif', '145.tif', '144.tif', '139.tif', '146.tif', '148.tif', '152.tif', '149.tif', '150.tif', '151.tif', '147.tif', '158.tif', '157.tif', '155.tif', '153.tif', '154.tif', '156.tif', '159.tif', '166.tif', '160.tif', '161.tif', '165.tif', '164.tif', '163.tif', '162.tif', '168.tif', '167.tif', '172.tif', '173.tif', '171.tif', '170.tif', '169.tif', '174.tif', '175.tif', '176.tif', '179.tif', '177.tif', '178.tif', '180.tif', '183.tif', '181.tif', '182.tif', '185.tif', '184.tif', '188.tif', '190.tif', '186.tif', '189.tif', '187.tif', '191.tif', '192.tif', '199.tif', '195.tif', '193.tif', '197.tif', '196.tif', '198.tif', '194.tif', '201.tif', '200.tif', '206.tif', '204.tif', '202.tif', '205.tif', '203.tif', '208.tif', '207.tif', '211.tif', '212.tif', '209.tif', '210.tif', '219.tif', '213.tif', '215.tif', '217.tif', '214.tif', '218.tif', '216.tif', '223.tif', '221.tif', '220.tif', '224.tif', '222.tif', '225.tif', '231.tif', '228.tif', '227.tif', '230.tif', '226.tif', '229.tif', '233.tif', '235.tif', '234.tif', '236.tif', '237.tif', '238.tif', '232.tif', '241.tif', '239.tif', '240.tif', '243.tif', '244.tif', '242.tif', '247.tif', '251.tif', '245.tif', '248.tif', '250.tif', '249.tif', '246.tif', '255.tif', '252.tif', '254.tif', '258.tif', '257.tif', '256.tif', '253.tif', '261.tif', '259.tif', '264.tif', '260.tif', '263.tif', '262.tif', '265.tif', '273.tif', '272.tif', '271.tif', '268.tif', '269.tif', '266.tif', '270.tif', '267.tif', '277.tif', '276.tif', '279.tif', '274.tif', '275.tif', '278.tif', '280.tif', '282.tif', '285.tif', '284.tif', '286.tif', '281.tif', '283.tif', '290.tif', '288.tif', '287.tif', '293.tif', '291.tif', '289.tif', '292.tif', '294.tif', '295.tif', '299.tif', '296.tif', '300.tif', '298.tif', '297.tif', '305.tif', '304.tif', '301.tif', '302.tif', '2.tif', '303.tif']

# %%
files[:5]
# Out:
# ['0.tif', '1.tif', '3.tif', '8.tif', '5.tif']

# %%
dir_name = "images"

# %%
sample_img_path = os.path.join(data_dir,dir_name[0])
sample_img_path
# Out:
# '/content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/data/i'

# %%
sample_img_path = "/content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/data/images/1.tif"
if sample_img_path.endswith((".tif", ".tiff")):
  with rasterio.open(sample_img_path) as src:
    img = src.read()
    print("image before movingaxis")
    print(img.shape)
    # Rasterio loads as (Channels, Height, Width). We move Channels to the end for plotting.
    # Because matplotlib expect images to have dim of (Height, Width, Channels)
    # So we move the dimension of Channels to the end Which is 12 channels
    img = np.moveaxis(img, 0, -1)
    print("image after movingaxis")
    print(img.shape)

else:
  print("Unkown file extension")
# Out:
# image before movingaxis
# (12, 128, 128)
# image after movingaxis
# (128, 128, 12)
# /usr/local/lib/python3.12/dist-packages/rasterio/__init__.py:367: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, thread_safe=thread_safe, **kwargs)

# %%
print(f"Image Shape: {img.shape}")
print(f"Image Size: {img.size}")
print(f"Data type: {img.dtype}")
print(f"Min Valu: {img.min()}, Max Value: {img.max()}")
# Out:
# Image Shape: (128, 128, 12)
# Image Size: 196608
# Data type: int16
# Min Valu: 0, Max Value: 6411

# %%
img.max()
# Out:
# np.int16(6411)

# %%
img
# Out:
# array([[[233, 182, 405, ..., 361,  10,   0],
#         [230, 182, 427, ..., 360,  30,   0],
#         [230, 174, 429, ..., 361,  10,   0],
#         ...,
#         [327, 299, 648, ..., 401,  30,   0],
#         [327, 315, 648, ..., 402,  30,   0],
#         [325, 341, 649, ..., 402,  30,   0]],
#
#        [[263, 292, 617, ..., 361,  10,   0],
#         [298, 309, 630, ..., 360,  30,   0],
#         [298, 203, 414, ..., 361,  10,   0],
#         ...,
#         [328, 257, 527, ..., 400,  30,   0],
#         [328, 418, 644, ..., 402,  10,   0],
#         [333, 398, 663, ..., 403,  30,   0]],
#
#        [[263, 369, 707, ..., 359,  30,   0],
#         [298, 348, 666, ..., 360,  30,   0],
#         [298, 234, 447, ..., 361,  10,   0],
#         ...,
#         [328, 272, 613, ..., 398,  10,   0],
#         [328, 333, 576, ..., 401,  10,   0],
#         [333, 300, 616, ..., 400,  10,   0]],
#
#        ...,
#
#        [[247, 221, 565, ..., 487,  10,   0],
#         [214, 131, 335, ..., 489,  10,   0],
#         [214,  91, 231, ..., 483,  10,   0],
#         ...,
#         [256, 223, 533, ..., 462,  30,   0],
#         [256, 216, 543, ..., 465,  30,   0],
#         [259, 221, 549, ..., 468,  30,   0]],
#
#        [[247, 206, 595, ..., 494,  30,   0],
#         [214, 216, 540, ..., 495,  10,   0],
#         [214, 206, 495, ..., 494,  10,   0],
#         ...,
#         [256, 238, 584, ..., 466,  30,   0],
#         [256, 224, 490, ..., 469,  30,   0],
#         [259, 217, 502, ..., 472,  30,   0]],
#
#        [[258, 219, 613, ..., 502,  30,   0],
#         [285, 249, 661, ..., 502,  30,   0],
#         [285, 319, 695, ..., 498,  30,   0],
#         ...,
#         [270, 290, 611, ..., 473,  30,   0],
#         [270, 317, 693, ..., 473,  30,   0],
#         [254, 235, 594, ..., 476,  30,   0]]], dtype=int16)

# %%
train_img_dir = "/content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/data/images"
train_img_mask = "/content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/data/labels"

# %% [markdown]
# Get Image and Mask filenames and Sort them to ensure matching

# %%
from numpy._core.defchararray import endswith
train_img_files = [f for f in sorted(os.listdir(train_img_dir)) if f.endswith(".tif")]
train_img_files
# Out:
# ['0.tif',
#  '1.tif',
#  '10.tif',
#  '100.tif',
#  '101.tif',
#  '102.tif',
#  '103.tif',
#  '104.tif',
#  '105.tif',
#  '106.tif',
#  '107.tif',
#  '108.tif',
#  '109.tif',
#  '11.tif',
#  '110.tif',
#  '111.tif',
#  '112.tif',
#  '113.tif',
#  '114.tif',
#  '115.tif',
#  '116.tif',
#  '117.tif',
#  '118.tif',
#  '119.tif',
#  '12.tif',
#  '120.tif',
#  '121.tif',
#  '122.tif',
#  '123.tif',
#  '124.tif',
#  '125.tif',
#  '126.tif',
#  '127.tif',
#  '128.tif',
#  '129.tif',
#  '13.tif',
#  '130.tif',
#  '131.tif',
#  '132.tif',
#  '133.tif',
#  '134.tif',
#  '135.tif',
#  '136.tif',
#  '137.tif',
#  '138.tif',
#  '139.tif',
#  '14.tif',
#  '140.tif',
#  '141.tif',
#  '142.tif',
#  '143.tif',
#  '144.tif',
#  '145.tif',
#  '146.tif',
#  '147.tif',
#  '148.tif',
#  '149.tif',
#  '15.tif',
#  '150.tif',
#  '151.tif',
#  '152.tif',
#  '153.tif',
#  '154.tif',
#  '155.tif',
#  '156.tif',
#  '157.tif',
#  '158.tif',
#  '159.tif',
#  '16.tif',
#  '160.tif',
#  '161.tif',
#  '162.tif',
#  '163.tif',
#  '164.tif',
#  '165.tif',
#  '166.tif',
#  '167.tif',
#  '168.tif',
#  '169.tif',
#  '17.tif',
#  '170.tif',
#  '171.tif',
#  '172.tif',
#  '173.tif',
#  '174.tif',
#  '175.tif',
#  '176.tif',
#  '177.tif',
#  '178.tif',
#  '179.tif',
#  '18.tif',
#  '180.tif',
#  '181.tif',
#  '182.tif',
#  '183.tif',
#  '184.tif',
#  '185.tif',
#  '186.tif',
#  '187.tif',
#  '188.tif',
#  '189.tif',
#  '19.tif',
#  '190.tif',
#  '191.tif',
#  '192.tif',
#  '193.tif',
#  '194.tif',
#  '195.tif',
#  '196.tif',
#  '197.tif',
#  '198.tif',
#  '199.tif',
#  '2.tif',
#  '20.tif',
#  '200.tif',
#  '201.tif',
#  '202.tif',
#  '203.tif',
#  '204.tif',
#  '205.tif',
#  '206.tif',
#  '207.tif',
#  '208.tif',
#  '209.tif',
#  '21.tif',
#  '210.tif',
#  '211.tif',
#  '212.tif',
#  '213.tif',
#  '214.tif',
#  '215.tif',
#  '216.tif',
#  '217.tif',
#  '218.tif',
#  '219.tif',
#  '22.tif',
#  '220.tif',
#  '221.tif',
#  '222.tif',
#  '223.tif',
#  '224.tif',
#  '225.tif',
#  '226.tif',
#  '227.tif',
#  '228.tif',
#  '229.tif',
#  '23.tif',
#  '230.tif',
#  '231.tif',
#  '232.tif',
#  '233.tif',
#  '234.tif',
#  '235.tif',
#  '236.tif',
#  '237.tif',
#  '238.tif',
#  '239.tif',
#  '24.tif',
#  '240.tif',
#  '241.tif',
#  '242.tif',
#  '243.tif',
#  '244.tif',
#  '245.tif',
#  '246.tif',
#  '247.tif',
#  '248.tif',
#  '249.tif',
#  '25.tif',
#  '250.tif',
#  '251.tif',
#  '252.tif',
#  '253.tif',
#  '254.tif',
#  '255.tif',
#  '256.tif',
#  '257.tif',
#  '258.tif',
#  '259.tif',
#  '26.tif',
#  '260.tif',
#  '261.tif',
#  '262.tif',
#  '263.tif',
#  '264.tif',
#  '265.tif',
#  '266.tif',
#  '267.tif',
#  '268.tif',
#  '269.tif',
#  '27.tif',
#  '270.tif',
#  '271.tif',
#  '272.tif',
#  '273.tif',
#  '274.tif',
#  '275.tif',
#  '276.tif',
#  '277.tif',
#  '278.tif',
#  '279.tif',
#  '28.tif',
#  '280.tif',
#  '281.tif',
#  '282.tif',
#  '283.tif',
#  '284.tif',
#  '285.tif',
#  '286.tif',
#  '287.tif',
#  '288.tif',
#  '289.tif',
#  '29.tif',
#  '290.tif',
#  '291.tif',
#  '292.tif',
#  '293.tif',
#  '294.tif',
#  '295.tif',
#  '296.tif',
#  '297.tif',
#  '298.tif',
#  '299.tif',
#  '3.tif',
#  '30.tif',
#  '300.tif',
#  '301.tif',
#  '302.tif',
#  '303.tif',
#  '304.tif',
#  '305.tif',
#  '31.tif',
#  '32.tif',
#  '33.tif',
#  '34.tif',
#  '35.tif',
#  '36.tif',
#  '37.tif',
#  '38.tif',
#  '39.tif',
#  '4.tif',
#  '40.tif',
#  '41.tif',
#  '42.tif',
#  '43.tif',
#  '44.tif',
#  '45.tif',
#  '46.tif',
#  '47.tif',
#  '48.tif',
#  '49.tif',
#  '5.tif',
#  '50.tif',
#  '51.tif',
#  '52.tif',
#  '53.tif',
#  '54.tif',
#  '55.tif',
#  '56.tif',
#  '57.tif',
#  '58.tif',
#  '59.tif',
#  '6.tif',
#  '60.tif',
#  '61.tif',
#  '62.tif',
#  '63.tif',
#  '64.tif',
#  '65.tif',
#  '66.tif',
#  '67.tif',
#  '68.tif',
#  '69.tif',
#  '7.tif',
#  '70.tif',
#  '71.tif',
#  '72.tif',
#  '73.tif',
#  '74.tif',
#  '75.tif',
#  '76.tif',
#  '77.tif',
#  '78.tif',
#  '79.tif',
#  '8.tif',
#  '80.tif',
#  '81.tif',
#  '82.tif',
#  '83.tif',
#  '84.tif',
#  '85.tif',
#  '86.tif',
#  '87.tif',
#  '88.tif',
#  '89.tif',
#  '9.tif',
#  '90.tif',
#  '91.tif',
#  '92.tif',
#  '93.tif',
#  '94.tif',
#  '95.tif',
#  '96.tif',
#  '97.tif',
#  '98.tif',
#  '99.tif']

# %%
train_mask_files = [f for f in sorted(os.listdir(train_img_mask)) if f.endswith(".png")]
train_mask_files
# Out:
# ['0.png',
#  '1.png',
#  '10.png',
#  '100.png',
#  '100_184.png',
#  '101.png',
#  '101_89.png',
#  '102.png',
#  '102_179.png',
#  '103.png',
#  '103_225.png',
#  '104.png',
#  '104_20.png',
#  '105.png',
#  '105_148.png',
#  '106.png',
#  '106_267.png',
#  '107.png',
#  '107_59.png',
#  '108.png',
#  '108_236.png',
#  '109.png',
#  '109_223.png',
#  '10_244.png',
#  '11.png',
#  '110.png',
#  '110_287.png',
#  '111.png',
#  '111_121.png',
#  '112.png',
#  '112_78.png',
#  '113.png',
#  '113_44.png',
#  '114.png',
#  '114_220.png',
#  '115.png',
#  '115_49.png',
#  '116.png',
#  '116_250.png',
#  '117.png',
#  '117_97.png',
#  '118.png',
#  '118_125.png',
#  '119.png',
#  '119_222.png',
#  '11_116.png',
#  '12.png',
#  '120.png',
#  '120_305.png',
#  '121.png',
#  '121_142.png',
#  '122.png',
#  '122_257.png',
#  '123.png',
#  '123_145.png',
#  '124.png',
#  '124_95.png',
#  '125.png',
#  '125_201.png',
#  '126.png',
#  '126_110.png',
#  '127.png',
#  '127_54.png',
#  '128.png',
#  '128_294.png',
#  '129.png',
#  '129_177.png',
#  '12_286.png',
#  '13.png',
#  '130.png',
#  '130_256.png',
#  '131.png',
#  '131_185.png',
#  '132.png',
#  '132_126.png',
#  '133.png',
#  '133_224.png',
#  '134.png',
#  '134_153.png',
#  '135.png',
#  '135_56.png',
#  '136.png',
#  '136_301.png',
#  '137.png',
#  '137_140.png',
#  '138.png',
#  '138_39.png',
#  '139.png',
#  '139_108.png',
#  '13_234.png',
#  '14.png',
#  '140.png',
#  '140_34.png',
#  '141.png',
#  '141_237.png',
#  '142.png',
#  '142_238.png',
#  '143.png',
#  '143_183.png',
#  '144.png',
#  '144_235.png',
#  '145.png',
#  '145_164.png',
#  '146.png',
#  '146_84.png',
#  '147.png',
#  '147_213.png',
#  '148.png',
#  '148_297.png',
#  '149.png',
#  '149_166.png',
#  '14_135.png',
#  '15.png',
#  '150.png',
#  '150_243.png',
#  '151.png',
#  '152.png',
#  '153.png',
#  '154.png',
#  '155.png',
#  '156.png',
#  '157.png',
#  '158.png',
#  '159.png',
#  '15_233.png',
#  '16.png',
#  '160.png',
#  '161.png',
#  '162.png',
#  '163.png',
#  '164.png',
#  '165.png',
#  '166.png',
#  '167.png',
#  '168.png',
#  '169.png',
#  '16_229.png',
#  '17.png',
#  '170.png',
#  '171.png',
#  '172.png',
#  '173.png',
#  '174.png',
#  '175.png',
#  '176.png',
#  '177.png',
#  '178.png',
#  '179.png',
#  '17_60.png',
#  '18.png',
#  '180.png',
#  '181.png',
#  '182.png',
#  '183.png',
#  '184.png',
#  '185.png',
#  '186.png',
#  '187.png',
#  '188.png',
#  '189.png',
#  '18_42.png',
#  '19.png',
#  '190.png',
#  '191.png',
#  '192.png',
#  '193.png',
#  '194.png',
#  '195.png',
#  '196.png',
#  '197.png',
#  '198.png',
#  '199.png',
#  '19_293.png',
#  '1_226.png',
#  '2.png',
#  '20.png',
#  '200.png',
#  '201.png',
#  '202.png',
#  '203.png',
#  '204.png',
#  '205.png',
#  '206.png',
#  '207.png',
#  '208.png',
#  '209.png',
#  '20_283.png',
#  '21.png',
#  '210.png',
#  '211.png',
#  '212.png',
#  '213.png',
#  '214.png',
#  '215.png',
#  '216.png',
#  '217.png',
#  '218.png',
#  '219.png',
#  '21_254.png',
#  '22.png',
#  '220.png',
#  '221.png',
#  '222.png',
#  '223.png',
#  '224.png',
#  '225.png',
#  '226.png',
#  '227.png',
#  '228.png',
#  '229.png',
#  '22_16.png',
#  '23.png',
#  '230.png',
#  '231.png',
#  '232.png',
#  '233.png',
#  '234.png',
#  '235.png',
#  '236.png',
#  '237.png',
#  '238.png',
#  '239.png',
#  '23_251.png',
#  '24.png',
#  '240.png',
#  '241.png',
#  '242.png',
#  '243.png',
#  '244.png',
#  '245.png',
#  '246.png',
#  '247.png',
#  '248.png',
#  '249.png',
#  '24_111.png',
#  '25.png',
#  '250.png',
#  '251.png',
#  '252.png',
#  '253.png',
#  '254.png',
#  '255.png',
#  '256.png',
#  '257.png',
#  '258.png',
#  '259.png',
#  '25_172.png',
#  '26.png',
#  '260.png',
#  '261.png',
#  '262.png',
#  '263.png',
#  '264.png',
#  '265.png',
#  '266.png',
#  '267.png',
#  '268.png',
#  '269.png',
#  '26_274.png',
#  '27.png',
#  '270.png',
#  '271.png',
#  '272.png',
#  '273.png',
#  '274.png',
#  '275.png',
#  '276.png',
#  '277.png',
#  '278.png',
#  '279.png',
#  '27_290.png',
#  '28.png',
#  '280.png',
#  '281.png',
#  '282.png',
#  '283.png',
#  '284.png',
#  '285.png',
#  '286.png',
#  '287.png',
#  '288.png',
#  '289.png',
#  '28_2.png',
#  '29.png',
#  '290.png',
#  '291.png',
#  '292.png',
#  '293.png',
#  '294.png',
#  '295.png',
#  '296.png',
#  '297.png',
#  '298.png',
#  '299.png',
#  '29_186.png',
#  '2_215.png',
#  '3.png',
#  '30.png',
#  '300.png',
#  '301.png',
#  '302.png',
#  '303.png',
#  '304.png',
#  '305.png',
#  '30_143.png',
#  '31.png',
#  '31_196.png',
#  '32.png',
#  '32_11.png',
#  '33.png',
#  '33_134.png',
#  '34.png',
#  '34_239.png',
#  '35.png',
#  '35_30.png',
#  '36.png',
#  '36_240.png',
#  '37.png',
#  '37_118.png',
#  '38.png',
#  '38_68.png',
#  '39.png',
#  '39_27.png',
#  '3_74.png',
#  '4.png',
#  '40.png',
#  '40_277.png',
#  '41.png',
#  '41_77.png',
#  '42.png',
#  '42_281.png',
#  '43.png',
#  '43_149.png',
#  '44.png',
#  '44_191.png',
#  '45.png',
#  '45_158.png',
#  '46.png',
#  '46_55.png',
#  '47.png',
#  '47_15.png',
#  '48.png',
#  '48_12.png',
#  '49.png',
#  '49_64.png',
#  '4_300.png',
#  '5.png',
#  '50.png',
#  '50_263.png',
#  '51.png',
#  '51_91.png',
#  '52.png',
#  '52_160.png',
#  '53.png',
#  '53_43.png',
#  '54.png',
#  '54_51.png',
#  '55.png',
#  '55_219.png',
#  '56.png',
#  '56_19.png',
#  '57.png',
#  '57_45.png',
#  '58.png',
#  '58_114.png',
#  '59.png',
#  '59_132.png',
#  '5_275.png',
#  '6.png',
#  '60.png',
#  '60_245.png',
#  '61.png',
#  '61_206.png',
#  '62.png',
#  '62_187.png',
#  '63.png',
#  '63_17.png',
#  '64.png',
#  '64_86.png',
#  '65.png',
#  '65_203.png',
#  '66.png',
#  '66_22.png',
#  '67.png',
#  '67_156.png',
#  '68.png',
#  '68_180.png',
#  '69.png',
#  '69_18.png',
#  '6_248.png',
#  '7.png',
#  '70.png',
#  '70_268.png',
#  '71.png',
#  '71_120.png',
#  '72.png',
#  '72_205.png',
#  '73.png',
#  '73_23.png',
#  '74.png',
#  '74_65.png',
#  '75.png',
#  '75_52.png',
#  '76.png',
#  '76_92.png',
#  '77.png',
#  '77_61.png',
#  '78.png',
#  '78_246.png',
#  '79.png',
#  '79_161.png',
#  '7_146.png',
#  '8.png',
#  '80.png',
#  '80_124.png',
#  '81.png',
#  '81_9.png',
#  '82.png',
#  '82_100.png',
#  '83.png',
#  '83_131.png',
#  '84.png',
#  '84_76.png',
#  '85.png',
#  '85_117.png',
#  '86.png',
#  '86_288.png',
#  '87.png',
#  '87_182.png',
#  '88.png',
#  '88_157.png',
#  '89.png',
#  '89_228.png',
#  '8_73.png',
#  '9.png',
#  '90.png',
#  '90_303.png',
#  '91.png',
#  '91_102.png',
#  '92.png',
#  '92_272.png',
#  '93.png',
#  '93_217.png',
#  '94.png',
#  '94_119.png',
#  '95.png',
#  '95_221.png',
#  '96.png',
#  '96_154.png',
#  '97.png',
#  '97_130.png',
#  '98.png',
#  '98_253.png',
#  '99.png',
#  '99_170.png',
#  '9_202.png']

# %%
print(len(train_img_files))
print(len(train_mask_files))
# Out:
# 306
# 456

# %% [markdown]
# # Handle images and masks count mismatch

# %%
text = '46_55.png'
set([os.path.splitext(text)[0]])
# Out:
# {'46_55'}

# %%
img_basenames = set([os.path.splitext(f)[0] for f in train_img_files])
mask_basenames = set([os.path.splitext(f)[0] for f in train_mask_files])

# %%
# Use Set Difference to Give me everything in the first set(img_basenames) that is missing from the second set(mask_basenames).
missing_masks = img_basenames - mask_basenames
missing_images = mask_basenames - img_basenames
print(f"Missing Masks: {len(missing_masks)}")
print(f"Missing images: {len(missing_images)}")
# Out:
# Missing Masks: 0
# Missing images: 150

# %% [markdown]
# The Fix : Only Keep the filenames that exist in Both folders images and masks

# %%
valid_basenames = img_basenames.intersection(mask_basenames)
print(f"Valid Basenames: {len(valid_basenames)}")
# Out:
# Valid Basenames: 306

# %%
# Rebuild the lists using ONLY the valid pairs, and SORT them so they align perfectly!
train_img_files = sorted([f"{name}.tif" for name in valid_basenames])
train_mask_files = sorted([f"{name}.png" for name in valid_basenames])
len(train_img_files) == len(train_mask_files)
# Out:
# True

# %% [markdown]
# Create a folder of preprocessed data after remove the mismatch images

# %%
preprocessed_img_dir = "/content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/preprocessed_data/images/"
preprocessed_mask_dir = "/content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/preprocessed_data/labels/"

# %%
os.makedirs(preprocessed_img_dir, exist_ok=True)
os.makedirs(preprocessed_mask_dir, exist_ok=True )

# %% [markdown]
# ## Create a copy of the matched images and masks into the preprocessed folder

# %%
for name in tqdm(valid_basenames):
  # Define the original raw files paths
  raw_img_path = os.path.join(train_img_dir, f"{name}.tif")
  raw_mask_path = os.path.join(train_img_mask, f"{name}.png")

  # Define the new destination paths
  new_img_path = os.path.join(preprocessed_img_dir, f"{name}.tif")
  new_mask_path = os.path.join(preprocessed_mask_dir, f"{name}.png")

  # Copy The files from the raw path to the new path
  shutil.copy(raw_img_path, new_img_path)
  shutil.copy(raw_mask_path, new_mask_path)
# Out:
# 100%|██████████| 306/306 [06:34<00:00,  1.29s/it]

# %%
len(os.listdir(preprocessed_img_dir)) == len(os.listdir(preprocessed_mask_dir))
# Out:
# True

# %%
def display_image_and_mask(img_path, mask_path):
  # Use the already defined load_image function to correctly read the .tif file
  img_multichannel = load_image(img_path)

  # For display, select a subset of channels, e.g., Red (Band 3), Green (Band 2), Blue (Band 1).
  # Adjust these indices if your desired visual representation changes.
  # Normalizing to 0-1 for display purposes.
  # Assuming bands are 0-indexed: Band 3 (Red) is index 3, Band 2 (Green) is index 2, Band 1 (Blue) is index 1
  display_img = img_multichannel[:, :, [3, 2, 1]].astype(np.float32) # Select RGB channels
  display_img = (display_img - display_img.min()) / (display_img.max() - display_img.min()) # Normalize for display

  mask = Image.open(mask_path)

  # Plot the image and mask side by side
  fig, axes = plt.subplots(1,2,figsize=(10,5))
  axes[0].imshow(display_img)
  axes[0].set_title("Image (RGB)")
  axes[0].axis("off")

  axes[1].imshow(mask,cmap="gray")
  axes[1].set_title("Mask")
  axes[1].axis("off")
  plt.show()

# %%
def load_image(img_path):
  """
  Loads a 12-channel .tif image and normalize it to [0,1].
  """
  # img_path is expected to be a Python string here, provided by process_image_for_tf
  with rasterio.open(img_path) as src:
    img = src.read()
    img = np.moveaxis(img, 0,-1) # Converts (12,H,W) to (H, W , 12)
  return img

# %%
def normalize_image(img):
  """
  Normalize the image to values betwen 0 and 1
  """
  img = img.astype(np.float32) / 10000.0
  img = np.clip(img, 0.0, 1.0)
  return img

# %% [markdown]
# # Visualize the images and it's mask Side by Side

# %%
# check that the number of images match the number of masks

if len(train_img_files) != len(train_mask_files):
  print("Not match")
else:

  # Display the first 7 image-mask pairs
  for img_file, mask_file in zip(train_img_files[:7], train_mask_files[:7]):

     # get the full path for the img and masks
     img_path = os.path.join(preprocessed_img_dir, img_file)
     mask_path = os.path.join(preprocessed_mask_dir, mask_file)

     display_image_and_mask(img_path=img_path, mask_path=mask_path)
# Out:
# /usr/local/lib/python3.12/dist-packages/rasterio/__init__.py:367: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, thread_safe=thread_safe, **kwargs)

# %% [markdown]
# Wrap our Custom Python Functions we have created so tensorflow can run them and understand the python code

# %% [markdown]
# # ⚙️ Building the Custom TensorFlow Data Pipeline
#
# For this water segmentation task, we are working with **12-channel multispectral satellite imagery** saved as `.tif` files, and binary masks saved as `.png` files.
#
# Because of the complex nature of this data, we cannot use standard high-level deep learning data loaders (like `tf.keras.preprocessing.ImageDataGenerator`). Instead, we must build a highly optimized `tf.data.Dataset` pipeline.
#
# ### 🚫 Why `ImageDataGenerator` Fails Here
# 1. **Channel Limitations:** `ImageDataGenerator` natively supports grayscale (1-channel) or RGB (3-channel) images. It will crash or silently drop 9 of our crucial bands if fed a 12-channel image.
# 2. **Scientific File Formats:** Standard loaders use libraries like PIL, which struggle with multi-band, georeferenced `.tif` files. We **must** use `rasterio` to safely extract the data.
# 3. **Improper Normalization:** Standard image scalers use `rescale=1./255`. However, raw satellite reflectance data is stored as 16-bit integers (`uint16`) scaled by 10,000. Dividing by 255 would destroy the data distribution.
#
# ---
#
# ### 🛠️ The Architecture of Our Pipeline
#
# To solve this, we split our data loading into three modular steps:
#
# [Image of TensorFlow data pipeline]
#
# #### 1. Python Utility Functions (`load_image` & `normalize_image`)
# These functions do the heavy lifting in pure Python:
# * **`rasterio.open()`**: Safely reads all 12 bands of the `.tif` file.
# * **`np.moveaxis()`**: `rasterio` loads images as `(Channels, Height, Width)`. We move the channels to the end `(Height, Width, Channels)` to match TensorFlow's expected Conv2D input format.
# * **`img / 10000.0`**: We reverse the space agency's storage scaling, bringing the true physical reflectance values back down to a decimal range that the neural network can mathematically process without exploding gradients.
#
# #### 2. The TensorFlow Bridge (`process_image_for_tf` & `process_mask_for_tf`)
# TensorFlow trains models at lightning speed by converting its operations into a compiled C++ computational graph. Because TensorFlow's C++ graph does not know how to run Python libraries like `rasterio` or `cv2`, we create these wrapper functions. They decode TensorFlow's byte-string file paths into standard Python strings so our utility functions can read them.
#
# #### 3. The Parser (`tf_parse`)
# This is the official translator for the `tf.data.Dataset`:
# * **`tf.py_function`**: This acts as a bridge. It tells TensorFlow to temporarily pause the C++ graph, jump out to Python, run our custom loading wrappers, and bring the resulting arrays back into the pipeline as `tf.float32` tensors.
# * **`set_shape()`**: When data passes through the `tf.py_function` black box, TensorFlow forgets its dimensions. We explicitly set the shapes to `[128, 128, 12]` for the images and `[128, 128, 1]` for the masks. The U-Net requires these explicit shapes to compile successfully.
#
# By structuring the pipeline this way, we achieve the perfect balance: the flexibility of Python (`rasterio`/`cv2`) combined with the extreme speed and GPU-prefetching capabilities of the `tf.data.Dataset` engine!

# %%
def process_image_for_tf(image_path_tensor):
  # image_path_tensor is a tf.Tensor object
  path = image_path_tensor.numpy().decode("utf-8") # Correctly get bytes from tf.Tensor, then decode

  img = load_image(path)
  img = normalize_image(img)
  return img

# %%
def process_mask_for_tf(mask_path_tensor):
  # mask_path_tensor is a tf.Tensor object
  path = mask_path_tensor.numpy().decode("utf-8") # Correctly get bytes from tf.Tensor, then decode
  mask = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
  # If the pixel is > 0 force it to be 1 else set it be zero
  mask = np.where(mask > 0, 1.0, 0.0).astype(np.float32)
  mask = np.expand_dims(mask, axis=-1) # Change (128,128) to (128, 128,1) for the u-net model
  return mask

# %%
def tf_parse(image_path, mask_path):
  image = tf.py_function(process_image_for_tf, [image_path], tf.float32) # Use the wrapper function
  mask = tf.py_function(process_mask_for_tf, [mask_path], tf.float32)

  image.set_shape([128, 128, 12])
  mask.set_shape([128,128,1])

  return image, mask

# %% [markdown]
# # Load and preprocess Images

# %%
img = load_image(img_path)
img.shape
# Out:
# /usr/local/lib/python3.12/dist-packages/rasterio/__init__.py:367: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, thread_safe=thread_safe, **kwargs)
# (128, 128, 12)

# %%
image_files = sorted([os.path.join(preprocessed_img_dir, f) for f in os.listdir(preprocessed_img_dir) if f.endswith(".tif")])
len(image_files)
# Out:
# 306

# %%
mask_files = sorted([os.path.join(preprocessed_mask_dir, f ) for f in os.listdir(preprocessed_mask_dir) if f.endswith(".png")])
len(mask_files)
# Out:
# 306

# %% [markdown]
# # Split the Data

# %% [markdown]
# Split the file paths

# %%
# 70% >> Train ,, 30% >> Temp
X_train, x_temp , y_train, y_temp = train_test_split(image_files, mask_files, test_size=0.3, random_state=42)
# 30% Temp >>> 15% Test
#          >>> 15% Valid

X_test, X_val, y_test, y_val = train_test_split(x_temp,y_temp, test_size=0.5, random_state=42)

len(X_train), len(X_val), len(X_test), len(y_train), len(y_val), len(y_test)
# Out:
# (214, 46, 46, 214, 46, 46)

# %%
dataset = tf.data.Dataset.from_tensor_slices((X_train,y_train))
dataset # Returns a Tensorflow object that combine the X_train and y_train
# Out:
# <_TensorSliceDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.string, name=None))>

# %%
def get_dataset(X_paths, y_paths, batch_size=16, is_training=False):
  """
    Creates an optimized TensorFlow Dataset pipeline for multispectral satellite imagery.

    This function takes raw file paths, pairs them, and builds a high-performance
    data loader that applies preprocessing, batching, and GPU prefetching.

    Args:
        x_paths (list of str): A list of file paths to the 12-channel .tif input images.
        y_paths (list of str): A list of file paths to the corresponding .png binary masks.
        batch_size (int, optional): The number of image/mask pairs to load per batch. Defaults to 16.
        is_training (bool, optional): A flag to enable data shuffling. Should be True for
                                      the training set and False for validation/testing. Defaults to False.

    Returns:
        tf.data.Dataset: A highly optimized, ready-to-train TensorFlow dataset object
                         yielding batches of shape (batch_size, 128, 128, 12) and (batch_size, 128, 128, 1).
    """
  # Create the dataset from the file paths
  dataset = tf.data.Dataset.from_tensor_slices((X_paths, y_paths))
  # If this is the training dataset, shuffle the order of the files
  # We set the buffer_size to the full length of the dataset for a perfect, completely random shuffle
  if is_training:
    dataset = dataset.shuffle(buffer_size=len(X_paths))
  # Apply our custom parsing function (tf_parse) to every file path
  # num_parallel_calls=tf.data.AUTOTUNE tells TF to use all available CPU cores to open multiple files at once
  dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
  dataset = dataset.batch(batch_size) # Add the batch dimension
  # This tells the CPU to prepare the next batch of images in the background
  # while the GPU is actively training on the current batch, preventing bottlenecks.
  dataset = dataset.prefetch(tf.data.AUTOTUNE)
  return dataset

# %% [markdown]
# CREATE The DATASET

# %%
train_dataset = get_dataset(X_train, y_train, batch_size=8, is_training=True)
val_dataset = get_dataset(X_val, y_val, batch_size=8, is_training=False)
test_dataset = get_dataset(X_test, y_test, batch_size=8, is_training=False)

# %%
train_dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 12), dtype=tf.float32, name=None), TensorSpec(shape=(None, 128, 128, 1), dtype=tf.float32, name=None))>

# %%
images, masks = next(iter(train_dataset))
images.shape
# Out:
# TensorShape([8, 128, 128, 12])

# %%
masks.shape
# Out:
# TensorShape([8, 128, 128, 1])

# %% [markdown]
# # Visualize the images that come from train_dataset

# %%
def display_array_and_mask(img_array, mask_array):
    """Visualizes arrays directly from the tf.data.Dataset batch"""

    # 1. Extract RGB channels (Bands 3, 2, 1) and normalize for display
    display_img = np.stack([img_array[:,:,3], img_array[:,:,2], img_array[:,:,1]], axis=-1)
    display_img = (display_img - np.min(display_img)) / (np.max(display_img) - np.min(display_img) + 1e-8)

    # 2. Plot side-by-side
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))

    axes[0].imshow(display_img)
    axes[0].set_title("Image (RGB)")
    axes[0].axis("off")

    # mask_array is (128, 128, 1), so we slice [:, :, 0] to make it (128, 128) for matplotlib
    axes[1].imshow(mask_array[:, :, 0], cmap="gray")
    axes[1].set_title("Mask")
    axes[1].axis("off")

    plt.show()

# %%
# Loop through the first 3 images in the batch we just generated
for i in range(3):
    print(f"Displaying Pair {i+1}")
    display_array_and_mask(images[i].numpy(), masks[i].numpy())
# Out:
# Displaying Pair 1
# Displaying Pair 2
# Displaying Pair 3

# %% [markdown]
# # Build U-Net Architecture

# %% [markdown]
# Create Our Helper functions

# %%
def conv_block(inputs, num_filters):
  """ A Standard Convolution Block for the U-Net Architecture"""
  # Apply the first Conv2D layer to the 'inputs' tensor
  x = Conv2D(num_filters, 3, padding="same", kernel_initializer="he_normal")(inputs)
  x = BatchNormalization()(x)
  x = Activation("relu")(x)

  # Apply the second Conv2D layer to the output of the previous activation
  x = Conv2D(num_filters, 3, padding="same", kernel_initializer="he_normal")(x)
  x = BatchNormalization()(x)
  x = Activation("relu")(x)

  return x

# %%
def encoder_block(inputs, num_filters):
    """The downward path: processes the image and then shrinks it."""
    # Process the features
    x = conv_block(inputs, num_filters)
    # Shrink the image size by half (e.g., 128x128 -> 64x64)
    p = MaxPooling2D((2, 2))(x)

    # We return BOTH 'x' (for the skip connection later) and 'p' (to continue downward)
    return x, p

# %%
def decoder_block(inputs, skip_features, num_filters):
    """The upward path: expands the image and merges it with the skip connections."""
    # Expand the image size by double (e.g., 64x64 -> 128x128)
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)

    # GLUE the expanding image together with the skipped features from the encoder
    x = Concatenate()([x, skip_features])

    # Process the merged features
    x = conv_block(x, num_filters)

    return x

# %%
def build_unet(input_shape=(128, 128, 12)):
    # --- INPUT ---
    inputs = Input(input_shape)

    # --- ENCODER (The Left Side of the "U") ---
    # s = skip connection output, p = pooled output to go to the next level
    s1, p1 = encoder_block(inputs, 64)   # 128x128 -> 64x64
    s2, p2 = encoder_block(p1, 128)      # 64x64 -> 32x32
    s3, p3 = encoder_block(p2, 256)      # 32x32 -> 16x16
    s4, p4 = encoder_block(p3, 512)      # 16x16 -> 8x8

    # --- BOTTLENECK (The Bottom of the "U") ---
    b1 = conv_block(p4, 1024)            # Stays 8x8, but has 1024 feature channels!

    # --- DECODER (The Right Side of the "U") ---
    d1 = decoder_block(b1, s4, 512)      # 8x8 -> 16x16 (merged with s4)
    d2 = decoder_block(d1, s3, 256)      # 16x16 -> 32x32 (merged with s3)
    d3 = decoder_block(d2, s2, 128)      # 32x32 -> 64x64 (merged with s2)
    d4 = decoder_block(d3, s1, 64)       # 64x64 -> 128x128 (merged with s1)

    # --- OUTPUT ---
    # We use exactly 1 filter because we only want a 1-channel output (the mask).
    # We use "sigmoid" because we want every pixel to be a probability between 0.0 (Land) and 1.0 (Water).
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    # Compile the final architecture
    model = Model(inputs, outputs, name="Water_Segmentation_UNet")
    return model

# Instantiate the model
model = build_unet()
model.summary()
# Out:
# Model: "Water_Segmentation_UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 128, 128,  │      6,976 │ input_layer_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 128, 128,  │     36,928 │ activation_18[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 64, 64,    │          0 │ activation_19[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 64, 64,    │     73,856 │ max_pooling2d_4[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 64, 64,    │    147,584 │ activation_20[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 32, 32,    │          0 │ activation_21[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 32, 32,    │    295,168 │ max_pooling2d_5[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 32, 32,    │    590,080 │ activation_22[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 16, 16,    │          0 │ activation_23[0]… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_6[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ activation_24[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 8, 8, 512) │          0 │ activation_25[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 8, 8,      │  4,719,616 │ max_pooling2d_7[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 8, 8,      │  9,438,208 │ activation_26[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 16, 16,    │  2,097,664 │ activation_27[0]… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 16, 16,    │  4,719,104 │ concatenate_4[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ activation_28[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 32, 32,    │    524,544 │ activation_29[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate_5[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 32, 32,    │    590,080 │ activation_30[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 64, 64,    │    131,200 │ activation_31[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 64, 64,    │    295,040 │ concatenate_6[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 64, 64,    │    147,584 │ activation_32[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 128, 128,  │     32,832 │ activation_33[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 128, 128,  │     73,792 │ concatenate_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 128, 128,  │     36,928 │ activation_34[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 128, 128,  │         65 │ activation_35[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,060,481 (118.49 MB)
#  Trainable params: 31,048,705 (118.44 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %% [markdown]
# CREATE THE Evaluation metric IOU

# %%
import tensorflow.keras.backend as K

def iou_metric(y_true, y_pred):
    """Calculates the Intersection over Union (IoU) metric."""
    # Convert the predicted probabilities (0.0 to 1.0) into a strict binary mask (0 or 1)
    # If the prediction is > 0.5 it will be 1 and If < 0.5 it will be zero
    y_pred = K.cast(K.greater(y_pred, 0.5), K.floatx())

    # Calculate intersection and union
    intersection = K.sum(y_true * y_pred)
    # |A U B| = |A| + |B| - |A intercect B|
    union = K.sum(y_true) + K.sum(y_pred) - intersection

    # Add a tiny epsilon to prevent division by zero
    # IOU = Intersection / Union
    # K.espilon that a tiny number to not zerodivisonerror by dividing by zero
    return (intersection + K.epsilon()) / (union + K.epsilon())

# %%
# Compile the U-Net
model.compile(
    optimizer=Adam(learning_rate=1e-4), # A small learning rate is safer for complex satellite data
    loss='binary_crossentropy',
    metrics=[iou_metric, 'accuracy']    # We track accuracy just for reference, but IoU is our main focus
)

print("Model successfully compiled!")
# Out:
# Model successfully compiled!

# %%
save_path = "/content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/Models/U-Net_Model.h5"
callbacks = [
    # 1. Save the best model automatically (so you don't lose it if Colab crashes)
    ModelCheckpoint(
        filepath= save_path,
        monitor='val_iou_metric',
        mode='max', # We want maximum IoU
        save_best_only=True,
        verbose=1
    ),

    # 2. Stop training if the model stops improving (prevents overfitting)
    EarlyStopping(
        monitor='val_iou_metric',
        mode='max',
        patience=15, # Wait 10 epochs without improvement before stopping
        restore_best_weights=True,
        verbose=1
    ),

    # 3. Slow down the learning rate when the model gets stuck
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2, # Reduce learning rate by 80%
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
]

# %%
EPOCHS = 20 # EarlyStopping will likely halt it before it hits 50

print("Starting training...")
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Starting training...
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 673ms/step - accuracy: 0.9796 - iou_metric: 0.9193 - loss: 0.0704
# Epoch 1: val_iou_metric improved from 0.78342 to 0.78575, saving model to /content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/Models/U-Net_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 27s 790ms/step - accuracy: 0.9796 - iou_metric: 0.9195 - loss: 0.0704 - val_accuracy: 0.9521 - val_iou_metric: 0.7857 - val_loss: 0.1494 - learning_rate: 2.0000e-05
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9807 - iou_metric: 0.9287 - loss: 0.0649
# Epoch 2: val_iou_metric did not improve from 0.78575
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 26s 356ms/step - accuracy: 0.9807 - iou_metric: 0.9287 - loss: 0.0650 - val_accuracy: 0.9519 - val_iou_metric: 0.7848 - val_loss: 0.1515 - learning_rate: 2.0000e-05
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.9824 - iou_metric: 0.9242 - loss: 0.0656
# Epoch 3: val_iou_metric did not improve from 0.78575
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 309ms/step - accuracy: 0.9823 - iou_metric: 0.9242 - loss: 0.0657 - val_accuracy: 0.9520 - val_iou_metric: 0.7852 - val_loss: 0.1511 - learning_rate: 2.0000e-05
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9785 - iou_metric: 0.9214 - loss: 0.0709
# Epoch 4: val_iou_metric improved from 0.78575 to 0.78678, saving model to /content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/Models/U-Net_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 395ms/step - accuracy: 0.9786 - iou_metric: 0.9216 - loss: 0.0707 - val_accuracy: 0.9521 - val_iou_metric: 0.7868 - val_loss: 0.1496 - learning_rate: 2.0000e-05
# Epoch 5/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.9813 - iou_metric: 0.9288 - loss: 0.0646
# Epoch 5: val_iou_metric did not improve from 0.78678
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 313ms/step - accuracy: 0.9813 - iou_metric: 0.9287 - loss: 0.0646 - val_accuracy: 0.9514 - val_iou_metric: 0.7806 - val_loss: 0.1530 - learning_rate: 2.0000e-05
# Epoch 6/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 617ms/step - accuracy: 0.9801 - iou_metric: 0.9176 - loss: 0.0712
# Epoch 6: val_iou_metric did not improve from 0.78678
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 18s 660ms/step - accuracy: 0.9800 - iou_metric: 0.9169 - loss: 0.0713 - val_accuracy: 0.9516 - val_iou_metric: 0.7831 - val_loss: 0.1521 - learning_rate: 2.0000e-05
# Epoch 7/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9825 - iou_metric: 0.9393 - loss: 0.0600
# Epoch 7: val_iou_metric did not improve from 0.78678
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 314ms/step - accuracy: 0.9825 - iou_metric: 0.9389 - loss: 0.0602 - val_accuracy: 0.9514 - val_iou_metric: 0.7823 - val_loss: 0.1538 - learning_rate: 4.0000e-06
# Epoch 8/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9821 - iou_metric: 0.9327 - loss: 0.0619
# Epoch 8: val_iou_metric did not improve from 0.78678
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 333ms/step - accuracy: 0.9821 - iou_metric: 0.9328 - loss: 0.0619 - val_accuracy: 0.9517 - val_iou_metric: 0.7841 - val_loss: 0.1535 - learning_rate: 4.0000e-06
# Epoch 9/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9814 - iou_metric: 0.9314 - loss: 0.0636
# Epoch 9: val_iou_metric improved from 0.78678 to 0.78738, saving model to /content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/Models/U-Net_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 757ms/step - accuracy: 0.9814 - iou_metric: 0.9314 - loss: 0.0636 - val_accuracy: 0.9522 - val_iou_metric: 0.7874 - val_loss: 0.1526 - learning_rate: 4.0000e-06
# Epoch 10/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9832 - iou_metric: 0.9367 - loss: 0.0588
# Epoch 10: val_iou_metric did not improve from 0.78738
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 311ms/step - accuracy: 0.9832 - iou_metric: 0.9365 - loss: 0.0590 - val_accuracy: 0.9520 - val_iou_metric: 0.7858 - val_loss: 0.1530 - learning_rate: 4.0000e-06
# Epoch 11/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 664ms/step - accuracy: 0.9805 - iou_metric: 0.9153 - loss: 0.0677
# Epoch 11: val_iou_metric did not improve from 0.78738
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1e-06.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 757ms/step - accuracy: 0.9806 - iou_metric: 0.9153 - loss: 0.0677 - val_accuracy: 0.9518 - val_iou_metric: 0.7847 - val_loss: 0.1538 - learning_rate: 4.0000e-06
# Epoch 12/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9819 - iou_metric: 0.9294 - loss: 0.0649
# Epoch 12: val_iou_metric did not improve from 0.78738
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 343ms/step - accuracy: 0.9819 - iou_metric: 0.9295 - loss: 0.0649 - val_accuracy: 0.9520 - val_iou_metric: 0.7857 - val_loss: 0.1537 - learning_rate: 1.0000e-06
# Epoch 13/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9823 - iou_metric: 0.9121 - loss: 0.0704
# Epoch 13: val_iou_metric did not improve from 0.78738
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 323ms/step - accuracy: 0.9823 - iou_metric: 0.9125 - loss: 0.0703 - val_accuracy: 0.9522 - val_iou_metric: 0.7868 - val_loss: 0.1528 - learning_rate: 1.0000e-06
# Epoch 14/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.9837 - iou_metric: 0.9358 - loss: 0.0585
# Epoch 14: val_iou_metric improved from 0.78738 to 0.78746, saving model to /content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/Models/U-Net_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 780ms/step - accuracy: 0.9835 - iou_metric: 0.9351 - loss: 0.0589 - val_accuracy: 0.9523 - val_iou_metric: 0.7875 - val_loss: 0.1529 - learning_rate: 1.0000e-06
# Epoch 15/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9819 - iou_metric: 0.9290 - loss: 0.0655
# Epoch 15: val_iou_metric did not improve from 0.78746
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 321ms/step - accuracy: 0.9819 - iou_metric: 0.9292 - loss: 0.0655 - val_accuracy: 0.9523 - val_iou_metric: 0.7874 - val_loss: 0.1530 - learning_rate: 1.0000e-06
# Epoch 16/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - accuracy: 0.9831 - iou_metric: 0.9254 - loss: 0.0648
# Epoch 16: val_iou_metric improved from 0.78746 to 0.78813, saving model to /content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/Models/U-Net_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 794ms/step - accuracy: 0.9831 - iou_metric: 0.9255 - loss: 0.0648 - val_accuracy: 0.9524 - val_iou_metric: 0.7881 - val_loss: 0.1522 - learning_rate: 1.0000e-06
# Epoch 17/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 681ms/step - accuracy: 0.9810 - iou_metric: 0.9259 - loss: 0.0663
# Epoch 17: val_iou_metric improved from 0.78813 to 0.78841, saving model to /content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/Models/U-Net_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9811 - iou_metric: 0.9262 - loss: 0.0662 - val_accuracy: 0.9524 - val_iou_metric: 0.7884 - val_loss: 0.1521 - learning_rate: 1.0000e-06
# Epoch 18/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 984ms/step - accuracy: 0.9783 - iou_metric: 0.8868 - loss: 0.0776
# Epoch 18: val_iou_metric improved from 0.78841 to 0.78857, saving model to /content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/Models/U-Net_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9783 - iou_metric: 0.8876 - loss: 0.0774 - val_accuracy: 0.9525 - val_iou_metric: 0.7886 - val_loss: 0.1518 - learning_rate: 1.0000e-06
# Epoch 19/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9828 - iou_metric: 0.9333 - loss: 0.0610
# Epoch 19: val_iou_metric improved from 0.78857 to 0.78859, saving model to /content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/Models/U-Net_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 16s 614ms/step - accuracy: 0.9828 - iou_metric: 0.9334 - loss: 0.0610 - val_accuracy: 0.9525 - val_iou_metric: 0.7886 - val_loss: 0.1519 - learning_rate: 1.0000e-06
# Epoch 20/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9825 - iou_metric: 0.9348 - loss: 0.0627
# Epoch 20: val_iou_metric improved from 0.78859 to 0.78885, saving model to /content/drive/MyDrive/Colab_Notebooks/Projects/Water Segmentation/Models/U-Net_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 792ms/step - accuracy: 0.9825 - iou_metric: 0.9347 - loss: 0.0627 - val_accuracy: 0.9525 - val_iou_metric: 0.7888 - val_loss: 0.1519 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 20.

# %% [markdown]
# # 🐛 Bug Fix: Image Binarization & The "NaN" ROC AUC Error
#
# ### The Symptoms
# During the model evaluation phase, three distinct issues occurred simultaneously:
# 1. **Loss Dropped to Zero:** The model appeared to be learning perfectly.
# 2. **IoU Flatlined:** The Intersection over Union metric remained stuck near `0.001`.
# 3. **ROC AUC Returned `nan`:** The Area Under the Curve calculation failed completely.
#
# ### The Root Cause
# The `nan` ROC AUC score is the most significant indicator of the problem. Mathematically, the ROC AUC metric requires both positive and negative examples to calculate the probability that a random positive example is scored higher than a random negative example. If a dataset (or batch) contains only a single class, the metric is undefined, and libraries like `scikit-learn` will return `nan`.
#
#
#
# This happened because the preprocessing code accidentally erased all the "Water" (positive) pixels from the dataset before the neural network even saw them.
#
# **The Flawed Logic:**
# ```python
# # Assuming a binary mask where Water = 1 and Land = 0
# mask = mask / 255.0  # 1 / 255.0 becomes 0.0039
# mask = np.round(mask) # 0.0039 rounds down to 0.0

# %%
# Load the best model
unet_model = load_model(save_path, custom_objects={"iou_metric": iou_metric})
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # Evaluate the model

# %%
test_loss, test_iou, test_acc = unet_model.evaluate(test_dataset)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test IoU (The ultimate score): {test_iou:.4f}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 468ms/step - accuracy: 0.9288 - iou_metric: 0.7942 - loss: 0.1976
# Test Loss: 0.1614
# Test Accuracy: 0.9447
# Test IoU (The ultimate score): 0.8025

# %%
# 3. Extract y_true and y_pred for ROC/AUC plotting
print("\nExtracting predictions for ROC calculation (this might take a minute)...")
y_true_list = []
y_pred_list = []

# Loop through the test dataset batch by batch
for images, masks in test_dataset:
    # Get the raw decimal probabilities from the U-Net
    preds = unet_model.predict(images, verbose=0)

    # Flatten the masks and predictions
    # Example: A (16, 128, 128, 1) batch becomes a flat list of 262,144 pixels
    y_true_list.extend(masks.numpy().flatten())
    y_pred_list.extend(preds.flatten())

# Convert the massive lists into fast NumPy arrays
y_true_all = np.array(y_true_list)
y_pred_all = np.array(y_pred_list)
# Out:
# Extracting predictions for ROC calculation (this might take a minute)...

# %%
# 4. Calculate the False Positive Rate, True Positive Rate, and AUC
print("Calculating ROC and AUC math...")
fpr, tpr, thresholds = roc_curve(y_true_all.astype(int), y_pred_all)
roc_auc = auc(fpr, tpr)

# 5. Plot the ROC Curve
plt.figure(figsize=(8, 6))

# Plot our model's performance line
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'U-Net ROC curve (AUC = {roc_auc:.4f})')

# Plot the "Random Guessing" baseline (the diagonal dashed line)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Guess (AUC = 0.5000)')

# Formatting the plot
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (Predicting Water when it is Land)')
plt.ylabel('True Positive Rate (Predicting Water correctly)')
plt.title('Receiver Operating Characteristic (ROC) - Water Segmentation')
plt.legend(loc="lower right")
plt.grid(alpha=0.3)

plt.show()
# Out:
# Calculating ROC and AUC math...

# %%
# Extract the metrics from the history object
loss = history.history['loss']
val_loss = history.history['val_loss']
iou = history.history['iou_metric']
val_iou = history.history['val_iou_metric']

# Find the number of epochs the model actually trained for
# (in case EarlyStopping kicked in early)
epochs = range(1, len(loss) + 1)

# %%
# Create a figure with 2 subplots side-by-side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
# --- Plot 1: Training and Validation Loss ---
ax1.plot(epochs, loss, 'b-', label='Training Loss')
ax1.plot(epochs, val_loss, 'r-', label='Validation Loss')
ax1.set_title('Training and Validation Loss (Binary Crossentropy)')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.grid(alpha=0.3)

# --- Plot 2: Training and Validation IoU ---
ax2.plot(epochs, iou, 'b-', label='Training IoU')
ax2.plot(epochs, val_iou, 'r-', label='Validation IoU')
ax2.set_title('Training and Validation IoU Metric')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('IoU Score')
ax2.legend()
ax2.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # We are Suspecting that the U-Net model is Overfitting because the IOU for training is 94% and for validation it's 80%

# %% [markdown]
# #### So we will Tune the model and apply some data augmentaion and add the dropout technique to the architecture of the U-Net and add the requlization term and handle the learning rate, Collect more data
